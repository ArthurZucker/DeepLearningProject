# %%
# !git clone -b main https://github.com/ArthurZucker/DeepLearningProject.git

# %%
# !ls
# %cd DeepLearningProject
# !mkdir wandb
# !ls
# !git branch

# %%
# !git pull

# %%
# !wandb login 1bd5c9f2298e5875d25866099bd98a8437c50cb6
# !wandb login

# %%
! pip install simple-parsing
! pip install lightning-bolts
! pip install vit-pytorch
! pip install pytorch-lightning
# !pip install rich

# %%
# !python main.py
